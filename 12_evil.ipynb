# %% [markdown]
# http://www.pythonchallenge.com/pc/return/evil.html

# %%
with open('c:/Users/25810/pythonchallenge/12_evil2.gfx', 'rb') as fin:
    data = fin.read()
    for i in range(5):
        with open('c:/Users/25810/pythonchallenge/12_%d.jpg' % i, 'wb')as fout:
            fout.write(data[i::5])

# %% [markdown]
# [disproportional](http://www.pythonchallenge.com/pc/return/disproportional.html)
