# %% [markdown]
# http://www.pythonchallenge.com/pc/def/ocr.html

# %%
with open('2_0.txt', 'r', encoding='utf-8') as f:
    s = f.read()

d = {}

for i in s:
    d[i] = d.get(i, 0) + 1

r = [k for k, v in d.items() if v == 1]
print(''.join(r))
# Out:
# equality

# %% [markdown]
# [equality](http://www.pythonchallenge.com/pc/def/equality.html)
