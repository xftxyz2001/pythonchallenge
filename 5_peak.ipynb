# %% [markdown]
# http://www.pythonchallenge.com/pc/def/peak.html

# %% [markdown]
# pickle

# %%
import pickle
import requests

response = requests.get('http://www.pythonchallenge.com/pc/def/banner.p')
o = pickle.loads(bytes(response.text, encoding='ascii'))
for line in o:
    print(''.join(s * c for s, c in line))
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...

# %% [markdown]
# [channel](http://www.pythonchallenge.com/pc/def/channel.html)
