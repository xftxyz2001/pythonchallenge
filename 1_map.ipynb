# %% [markdown]
# http://www.pythonchallenge.com/pc/def/map.html

# %%
s = "g fmnc wms bgblr rpylqjyrc gr zw fylb. rfyrq ufyr amknsrcpq ypc dmp. bmgle gr gl zw fylb gq glcddgagclr ylb rfyr'q ufw rfgq rcvr gq qm jmle. sqgle qrpgle.kyicrpylq() gq pcamkkclbcb. lmu ynnjw ml rfc spj."
for i in s:
    if i.isalpha():
        if ord(i) + 2 > ord('z'):
            print(chr(ord(i) + 2 - 26), end='')
        else:
            print(chr(ord(i) + 2), end='')
    else:
        print(i, end = "")
# Out:
# i hope you didnt translate it by hand. thats what computers are for. doing it in by hand is inefficient and that's why this text is so long. using string.maketrans() is recommended. now apply on the url.

# %% [markdown]
# 我希望你不是手工翻译的。这就是电脑的作用。手工计算效率很低，这就是为什么这篇文章这么长。建议使用string.maketrans()。现在应用到url上。

# %%
url = 'http://www.pythonchallenge.com/pc/def/map.html'
for i in url:
    if i.isalpha():
        if ord(i) + 2 > ord('z'):
            print(chr(ord(i) + 2 - 26), end='')
        else:
            print(chr(ord(i) + 2), end='')
    else:
        print(i, end = "")
# Out:
# jvvr://yyy.ravjqpejcnngpig.eqo/re/fgh/ocr.jvon

# %% [markdown]
# [ocr](http://www.pythonchallenge.com/pc/def/ocr.html)
