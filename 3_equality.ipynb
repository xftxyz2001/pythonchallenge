# %%
http://www.pythonchallenge.com/pc/def/equality.html

# %%
with open('3_0.txt', 'r', encoding='utf-8') as f:
    text = f.read()

import re
text = re.findall('[^A-Z][A-Z]{3}([a-z])[A-Z]{3}[^A-Z]', text)
print(''.join(text))
# Out:
# linkedlist

# %% [markdown]
# [linkedlist](http://www.pythonchallenge.com/pc/def/linkedlist.html)
# [linkedlist.php](http://www.pythonchallenge.com/pc/def/linkedlist.php)
